# %% [markdown]
# <div style="text-align:center;">
#   <strong><h1 style="font-size:2em;">Data analysis of job offers extracted from Linkedin by webscraping</h1></strong>
#   <strong><h1 style="font-size:2em;">(The dataset was created November 2023)</h1></strong>
# </div>

# %%
import pandas as pd

# %%
# Comprobar codificación del dataset si es necesario
import chardet

# Detect the encoding of the file

filename = 'job_offers_data_analytics.txt'
with open(filename, 'rb') as f:
    result = chardet.detect(f.read())

print(result)
# Out:
# {'encoding': 'Windows-1254', 'confidence': 0.5493291361121226, 'language': 'Turkish'}

# %%
# Loading the dataset

import pandas as pd

filename = 'job_offers_data_analytics.txt'

df = pd.read_csv(filename, header=None, sep='\t', names = ['Title','Company', 'Location', 'Description'])
df
# Out:
#                                                  Title  \
# 0                                  Online Data Analyst
# 1         Junior Operations Data Analyst (They/She/He)
# 2                                         Data Analyst
# 3                         Data Engineer / Data Analyst
# 4    Data Analyst (Bangkok Based, relocation provided)
# ..                                                 ...
# 116                      Senior Marketing Data Analyst
# 117                    Consultor Business Intelligence
# 118                                  Analista de datos
# 119  Data Analyst Bootcamp and Project Work (remote...
# 120  INVESTIGADOR/A ÁMBITO TECNOLOGÍAS BIOLÓGICAS A...
#
#                                        Company  \
# 0                          TELUS International
# 1                                        Glovo
# 2                                Carl Friedrik
# 3                                       ISPROX
# 4                                        Agoda
# ..                                         ...
# 116                                     Madbox
# 117                                  Consulsap
# 118                                 Voiping US
# 119                                      Moyyn
# 120  Eurecat - Centro Tecnológico de Catalunya
#
#                                   Location  \
# 0     Gerona, Cataluña, España (En remoto)
# 1    Barcelona, Cataluña, España (Híbrido)
# 2    Barcelona, Cataluña, España (Híbrido)
# 3     Badalona, Cataluña, España (Híbrido)
# 4              Barcelona, Cataluña, España
# ..                                     ...
# 116  Barcelona, Cataluña, España (Híbrido)
# 117            Barcelona, Cataluña, España
# 118                     España (En remoto)
# 119                     España (En remoto)
# 120    Manresa, Cataluña, España (Híbrido)
#
#                                            Description
# 0                  We are hiring freelance Spanish ...
# 1                  We are hiring freelance Spanish ...
# 2                  SummaryCarl Friedrik is a travel...
# 3                  Desde ISPROX estamos buscando in...
# 4                  About AgodaAgoda is an online tr...
# ..                                                 ...
# 116                Madbox is a mobile gaming compan...
# 117                         Este anuncio proviene d...
# 118                ¡En Voiping US seleccionamos Tal...
# 119                If you are a student, a recent g...
# 120                La UT Agua, Aire y Suelo (WAS) d...
#
# [121 rows x 4 columns]

# %%
# Convert the dataframe into an SQLite database
import sqlite3
db_file='../job_offers_data_analytics.db'
conn = sqlite3.connect(db_file)

df.to_sql(name='job_offers', con=conn, index=False, if_exists='replace')

conn.close()

# %% [markdown]
# ### Companies that have published more than one job offer

# %%
# Companies that have published more than one job offer

df['Company'].value_counts()[df['Company'].value_counts()>1]  # Compañias que han publicado más de 1 oferta
# Out:
# Glovo                                    11
# Capgemini                                 3
# Capgemini Engineering                     3
# eDreams ODIGEO                            3
# Agoda                                     3
# Criteo                                    3
# TELUS International AI Data Solutions     3
# Forcadell                                 3
# knowmad mood                              3
# Rhams Talent                              3
# Garaje de ideas                           3
# Bluetab, an IBM Company                   3
# TecAlliance                               2
# HR NET CONSULTING                         2
# TELUS International                       2
# Leadtech Group                            2
# Michael Page                              2
# GOOSE Recruitment                         2
# EsadeGov                                  2
# Deel                                      2
# Allianz Technology                        2
# HelloMrLead                               2
# Moyyn                                     2
# Name: Company, dtype: int64

# %% [markdown]
# ### Find similar or identical job offers for a given company

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

df_company = df[df['Company'] == 'Glovo']

# Create a TF-IDF vectorizer
vectorizer = TfidfVectorizer()

# Apply the vectorizer to the 'Description' column
tfidf_matrix = vectorizer.fit_transform(df_company['Description'])

# Calculate the cosine similarity matrix
similarity_matrix = cosine_similarity(tfidf_matrix, tfidf_matrix)

# Convert the similarity matrix to a DataFrame for better visualization
similarity_df = pd.DataFrame(similarity_matrix, columns=df_company.index, index=df_company.index)

# Display the similarity matrix DataFrame
similarity_df
# Out:
#           1         8         26        49        66        70        71  \
# 1   1.000000  0.437863  0.445272  0.443322  0.453114  0.462789  0.453352
# 8   0.437863  1.000000  0.890677  0.891784  0.889318  0.889556  0.893467
# 26  0.445272  0.890677  1.000000  0.975289  0.936279  0.892400  0.961395
# 49  0.443322  0.891784  0.975289  1.000000  0.941950  0.895927  0.964791
# 66  0.453114  0.889318  0.936279  0.941950  1.000000  0.893328  0.942869
# 70  0.462789  0.889556  0.892400  0.895927  0.893328  1.000000  0.905908
# 71  0.453352  0.893467  0.961395  0.964791  0.942869  0.905908  1.000000
# 81  0.432805  0.860882  0.857914  0.847246  0.844551  0.849180  0.853781
# 88  0.450525  0.899004  0.940764  0.945953  0.977084  0.901421  0.947345
# 92  0.443322  0.891784  0.975289  1.000000  0.941950  0.895927  0.964791
# 93  0.451185  0.871029  0.875600  0.879133  0.871155  0.861097  0.867394
#
#           81        88        92        93
# 1   0.432805  0.450525  0.443322  0.451185
# 8   0.860882  0.899004  0.891784  0.871029
# 26  0.857914  0.940764  0.975289  0.875600
# 49  0.847246  0.945953  1.000000  0.879133
# 66  0.844551  0.977084  0.941950  0.871155
# 70  0.849180  0.901421  0.895927  0.861097
# 71  0.853781  0.947345  0.964791  0.867394
# 81  1.000000  0.854905  0.847246  0.838066
# 88  0.854905  1.000000  0.945953  0.876817
# 92  0.847246  0.945953  1.000000  0.879133
# 93  0.838066  0.876817  0.879133  1.000000

# %%
df.iloc[244]['Description']

# %%
df.iloc[32]['Description']

# %% [markdown]
# ### Find common datascience terms in the job ooffers

# %%
# List of terms
term_list = ['Excel','Google Sheets','Python','Pyspark', 'Pandas', 'Matplotlib', 'Spark', 'Ray', 'AWS', 'GCP', 'Google Cloud', 'Azure',
             'Redshift', 'Snowflake', 'Tensorflow', 'Pytorch', 'JAX', 'SQL', 'Git', 'Github', 'Kubeflow', 'Airflow',
             'Flink', 'Kibana', 'Tableau', 'Transformers', 'SpaCy', 'NLTK', 'RAG', 'Looker Studio', 'Power BI', 'Redshift',
             'Snowflake', 'Docker', 'Azkaban', 'Docker', 'Kubernetes', 'DAX', 'Visual Basic', 'Scala','SAS', 'Qlik Sense', 'Qlik View',
             'QlikSense', 'QlikView', 'Quicksight', 'Microstrategy', 'Adobe Analytics', 'Google Analytics', 'dbt', 'Matlab', 
            'Periscope', 'Amplitude', 'ContentSquare', 'Bloomreach', 'Databricks', 'Jupyter', 'iPython', 'HubSpot', 'Salesforce',
             'Marketo', 'Dreamdata', 'Snowflake', 'BigQuery'

 ]

term_list1 = term_list + [term.lower() for term in term_list]  # include lowercase versions of the terms

term_list_upper = [term.upper() for term in term_list]

import re

# Function to find matching terms in a text (case-insensitive)
def find_matching_terms(text, terms):
    if isinstance(text, str):  # Check if the value is a valid string
        text_lower = text.lower()  # Convert the text to lowercase
        matching_terms = [term.upper() for term in terms if re.search(r'\b' + re.escape(term.lower()) + r'\b', text_lower)]
        return ', '.join(matching_terms)
    else:
        return ''  # Return an empty string for NaN values

# Create a new column with matching terms
df['Terms'] = df['Description'].apply(lambda x: find_matching_terms(x, term_list1))


df
# Out:
#                                                  Title  \
# 0                                  Online Data Analyst
# 1         Junior Operations Data Analyst (They/She/He)
# 2                                         Data Analyst
# 3                         Data Engineer / Data Analyst
# 4    Data Analyst (Bangkok Based, relocation provided)
# ..                                                 ...
# 116                      Senior Marketing Data Analyst
# 117                    Consultor Business Intelligence
# 118                                  Analista de datos
# 119  Data Analyst Bootcamp and Project Work (remote...
# 120  INVESTIGADOR/A ÁMBITO TECNOLOGÍAS BIOLÓGICAS A...
#
#                                        Company  \
# 0                          TELUS International
# 1                                        Glovo
# 2                                Carl Friedrik
# 3                                       ISPROX
# 4                                        Agoda
# ..                                         ...
# 116                                     Madbox
# 117                                  Consulsap
# 118                                 Voiping US
# 119                                      Moyyn
# 120  Eurecat - Centro Tecnológico de Catalunya
#
#                                   Location  \
# 0     Gerona, Cataluña, España (En remoto)
# 1    Barcelona, Cataluña, España (Híbrido)
# 2    Barcelona, Cataluña, España (Híbrido)
# 3     Badalona, Cataluña, España (Híbrido)
# 4              Barcelona, Cataluña, España
# ..                                     ...
# 116  Barcelona, Cataluña, España (Híbrido)
# 117            Barcelona, Cataluña, España
# 118                     España (En remoto)
# 119                     España (En remoto)
# 120    Manresa, Cataluña, España (Híbrido)
#
#                                            Description  \
# 0                  We are hiring freelance Spanish ...
# 1                  We are hiring freelance Spanish ...
# 2                  SummaryCarl Friedrik is a travel...
# 3                  Desde ISPROX estamos buscando in...
# 4                  About AgodaAgoda is an online tr...
# ..                                                 ...
# 116                Madbox is a mobile gaming compan...
# 117                         Este anuncio proviene d...
# 118                ¡En Voiping US seleccionamos Tal...
# 119                If you are a student, a recent g...
# 120                La UT Agua, Aire y Suelo (WAS) d...
#
#                                                  Terms   RAG
# 0                                                       None
# 1                                                       None
# 2       SQL, TABLEAU, BIGQUERY, SQL, TABLEAU, BIGQUERY  None
# 3    SQL, TABLEAU, MICROSTRATEGY, SQL, TABLEAU, MIC...  None
# 4    PYTHON, PANDAS, SQL, TABLEAU, POWER BI, SAS, P...  None
# ..                                                 ...   ...
# 116                                           SQL, SQL  None
# 117  SQL, QLIKSENSE, QLIKVIEW, SQL, QLIKSENSE, QLIK...  None
# 118                                                     None
# 119                                     PYTHON, PYTHON  None
# 120                                                     None
#
# [121 rows x 6 columns]

# %% [markdown]
# ### Find job offers with no common terms

# %%
df[df['Terms'] == '']
# Out:
#                                                  Title  \
# 72                            DATA ANALYST - RETENTION
# 82                                        Consultor BI
# 95   Key Expert II: Data analyst in transport secto...
# 118                                  Analista de datos
#
#                                   Company  \
# 72   MCR International | Executive Search
# 82              FRG Technology Consulting
# 95                  NTU International A/S
# 118                            Voiping US
#
#                                      Location  \
# 72   Barcelona, Cataluña, España (Presencial)
# 82                Barcelona, Cataluña, España
# 95                         España (En remoto)
# 118                        España (En remoto)
#
#                                            Description Terms
# 72                 Descripción Del Trabajo / Job De...
# 82                 Actualmente seleccionamos un per...
# 95                 NTU International as the consort...
# 118                ¡En Voiping US seleccionamos Tal...

# %%
df.iloc[25]['Description']
# Out:
# '              ¿Cuál será tu misión? ✍Te involucrarás en aspectos relacionados con análisis técnicos, transformación de datos y cuadros de mandos de todos proyectos en los que participes. ¿Cómo podrás hacerlo? Aprendiendo todo lo posible a nivel técnico y, poco a poco, te haremos ganar confianza en ti mismo e irás contando con la capacidad de gestionar tu propio tiempo y cada vez trabajar con mayor autonomía.Te encargarás también de la redacción de la documentación del proyecto en el que participes.Participarás en el análisis funcional de los proyectos, lo que te permitirá entender el negocio y tener una visión global y mayor conocimiento de los clientes. ¿Qué te hará triunfar en esta posición? 👇 Que estés en último curso o hayas finalizado tus estudios en Ingeniería Informática, Telecomunicaciones, Ciencia de datos, Industriales u otra salida académica que te haya dotado de capacidad de desarrollo y pensamiento crítico en este ambiente.Valoraremos muy positivamente formación adicional en Analytics, Big Data, o alguna disciplina similar, si no cuentas con ella no te preocupes ya que ¡estamos para aprender!Buscamos apasionadxs de los datos con espíritu innovador y muchas ganas de crecer con nosotrxs ya que podrás participar en proyectos que se mueven en entornos cambiantes en los que podrás tener un aprendizaje continuo.Capacidad de comunicación de cara a tus compañerxs, es muy importante para nosotrxs que puedas coordinarte con ellxs, apoyarles y levantar la mano para pedir ayuda.Cómo trabajamos en un entorno global, ¡será necesario que puedas comunicarte en inglés!  Información adicional ¡Hola Data Lover! 💙En SDG, no solo tendrás la oportunidad de formar parte de algo increíble, ¡sino que vivirás lo que significa ser un auténtico especialista en Data & Analytics!¿Estás preparadx para embarcarte en esta emocionante aventura? con nosotrxs, podrás potenciar todas tus habilidades y capacidades analíticas, tecnológicas y de negocio.¡Es hora de despegar hacia el futuro mediante el poder de los datos! Únete a nosotros y prepárate para romper las reglas y alcanzar tu mejor versión 🚀✨.Descubre el poder de SDG: líderes globales en la industria del dato 💥📊En SDG trabajamos para la mitad de las empresas del IBEX-35, pero también en multitud de compañías internacionales. Gracias al boom de la analítica, estamos en un ritmo constante de crecimiento, y desde 1994 nos hemos convertido en el socio de confianza para empresas que desean maximizar todo el potencial de sus datos.Si buscas formar parte de una compañía 100% especializada en #Data & #Analytics, ¡te estamos esperando!¿Qué nos hace diferentes? 🧐En nuestros proyectos, los datos y la tecnología son los protagonistas, te formaremos para que puedas trabajar con lo último del mercado (tenemos un área de innovación dónde impulsamos nuevos partnerships con fabricantes tecnológicos y centros de I+D).Tendrás todas las oportunidades para alcanzar tu mejor versión, con un plan de carrera totalmente personalizado en el que aprenderás por ti mismo y además, contarás con el apoyo del resto de compañerxs.Tu mismo te marcarás tus propios tiempos, semestralmente hablarás con tu responsable para compartir feedback y nuevos retos, y en base a tus resultados, habrá una revisión salarial.Somos una gran familia, desde el minuto 1 trataremos de hacerte la vida más fácil. Tanto tus compañerxs como el resto de equipo siempre tendrán una sonrisa y estarán dispuestos a ayudarte y ofrecerte todo su apoyo.Colaborarás y trabajarás en tu día a día con grandes referentes (técnicos y/o de negocio), estarán encantados de enseñarte todo lo posible y se sentirán orgullosxs de verte crecer.Con nosotros el Smartwork es posible. Vivirás una forma de trabajo en la que cada uno gestiona su propio tiempo.¿Quieres trabajar 100% en remoto?¿Quieres un modelo híbrido?En SDG podrás elegir cómo quieres trabajar, aunque creemos que es importante ponernos cara más allá de la pantalla ¡Te esperaremos en los Afterworks!Somos una marca  ...

# %% [markdown]
# ### Most used datascience tools

# %%
# Count occurrences of each term in the "MatchingTerms" column
term_counts = {term: df['Terms'].str.count(term).sum() for term in term_list_upper}

# Sort terms by the number of occurrences in descending order
sorted_terms = sorted(term_counts.items(), key=lambda x: x[1], reverse=True)

# Display the sorted terms and their counts
for term, count in sorted_terms:
    print(f'{term}: {count}')
# Out:
# SQL: 146
# PYTHON: 122
# POWER BI: 76
# TABLEAU: 58
# EXCEL: 50
# DAX: 30
# SAS: 30
# SNOWFLAKE: 24
# REDSHIFT: 20
# AWS: 18
# GOOGLE ANALYTICS: 14
# BIGQUERY: 14
# AZURE: 12
# GIT: 12
# QLIKVIEW: 12
# PANDAS: 10
# AMPLITUDE: 10
# GOOGLE CLOUD: 8
# MICROSTRATEGY: 8
# DBT: 8
# JUPYTER: 8
# IPYTHON: 8
# QLIK SENSE: 6
# ADOBE ANALYTICS: 6
# SALESFORCE: 6
# GOOGLE SHEETS: 4
# SPARK: 2
# GCP: 2
# GITHUB: 2
# LOOKER STUDIO: 2
# QLIK VIEW: 2
# QLIKSENSE: 2
# QUICKSIGHT: 2
# MATLAB: 2
# PERISCOPE: 2
# CONTENTSQUARE: 2
# BLOOMREACH: 2
# DATABRICKS: 2
# HUBSPOT: 2
# PYSPARK: 0
# MATPLOTLIB: 0
# RAY: 0
# TENSORFLOW: 0
# PYTORCH: 0
# JAX: 0
# KUBEFLOW: 0
# AIRFLOW: 0
# FLINK: 0
# KIBANA: 0
# TRANSFORMERS: 0
# SPACY: 0
# NLTK: 0
# RAG: 0
# DOCKER: 0
# AZKABAN: 0
# KUBERNETES: 0
# VISUAL BASIC: 0
# SCALA: 0
# MARKETO: 0
# DREAMDATA: 0

# %%
import matplotlib.pyplot as plt

# Count occurrences of each term in the "Terms" column
term_counts = {term: df['Terms'].str.count(term).sum() for term in term_list_upper}

# Filter out terms with zero counts
nonzero_terms = {term: count for term, count in term_counts.items() if count > 0}

# Sort terms by the number of occurrences in descending order
sorted_terms = sorted(nonzero_terms.items(), key=lambda x: x[1], reverse=True)

# Plot a histogram of term occurrences
plt.figure(figsize=(10, 4))
plt.bar([term[0] for term in sorted_terms], [term[1] for term in sorted_terms])
plt.ylabel('Count')
plt.title('Term Occurrences (Nonzero Counts Only)')
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better visibility
plt.tight_layout()
plt.show()

# %%
df.iloc[12]['Description']
# Out:
# '              Gaming:Welcome to the world of land-based gaming. Light & Wonder’s gaming team builds cutting-edge technology, products, and content for the most iconic casinos and operators across the globe.Position SummaryWe are looking for a confident analyst to join our dynamic Business Intelligence and Analytics team. As a key member, you will play a pivotal role in analyzing data and collaborating with key stakeholders to enhance various aspects of our operations. Working closely with cross-functional teams and management, you will identify areas for improvement and craft data-driven solutions.This role encompasses reporting, dashboard development, and solving analytical problems. The ideal candidate should be adept at collaborating with management at all levels to provide insights into driving efficiency and improvements within the Operations environment. The successful Operations Analyst will be self-motivated to learn diverse technologies and analytical methodologies.Please note that sponsorship is unavailable for this position.Objectives of this Role Collaborate with Operations teams to leverage data and insights, demonstrating operational savings and driving efficiencies.Work with department heads to assess and optimize workflow processes.Design, execute, and communicate analyses that uncover meaningful trends and opportunities across the business.Participate in regular management meetings, addressing issues and implementing improvements for efficient operations.Provide timely and robust analytic decision support to business partners and various organizational stakeholders. Daily and Monthly Responsibilities Manage the full lifecycle of analytics projects, from documenting project requirements to design and execution, including data pulling, manipulation, and export.Evaluate key performance indicators, generate ongoing reports, and recommend areas for improvement.Develop and implement data analyses, utilizing actual operational data to guide data-based decision-making.Prepare, analyze, and summarize weekly, monthly, and periodic analytical results for key stakeholders, creating reports, specifications, dashboards, and instructions. Qualifications Minimum of 1 years experience in an office environment (ideally a similar role)English and Spanish language both written and verbalStrong computer and logical/analytical skillsExperience working with Tableau or any other data visualization toolsWorking knowledge of Python (desirable)Proficient in Excel and MS-OfficeExperience and knowledge of SQL The Ideal Candidate Will Demonstrate: Ability to work both independently and collaboratively within a team.Passion for presenting data and trends, with the confidence to articulate the correctness of the data.Ability to thrive under tight deadlines and effective time management.Passion for the subject matter, showcasing how you delved into the problem to assist stakeholders in reaching informed conclusions.Enthusiasm for data, technology, and personal development.Eagerness to develop technical skills using new technology.Creative problem-solving approach with a commitment to professional growth. Light & Wonder are an Equal Opportunity Employer and encourage applications from all walks of life regardless of age, disability, sex, gender reassignment, sexual orientation, pregnancy and maternity, race, religion or belief and marriage and civil partnerships.If you are invited to an interview, please let us know if there are any reasonable adjustments, we can make to the recruitment process that will enable you to perform to the best of your ability.'

# %% [markdown]
# ### Find how many job offers imply hybrid or remote work

# %%
df['Regime'] = df['Location'].str.extract(r'\((.*?)\)')
df
# Out:
#                                                  Title  \
# 0                                  Online Data Analyst
# 1         Junior Operations Data Analyst (They/She/He)
# 2                                         Data Analyst
# 3                         Data Engineer / Data Analyst
# 4    Data Analyst (Bangkok Based, relocation provided)
# ..                                                 ...
# 116                      Senior Marketing Data Analyst
# 117                    Consultor Business Intelligence
# 118                                  Analista de datos
# 119  Data Analyst Bootcamp and Project Work (remote...
# 120  INVESTIGADOR/A ÁMBITO TECNOLOGÍAS BIOLÓGICAS A...
#
#                                        Company  \
# 0                          TELUS International
# 1                                        Glovo
# 2                                Carl Friedrik
# 3                                       ISPROX
# 4                                        Agoda
# ..                                         ...
# 116                                     Madbox
# 117                                  Consulsap
# 118                                 Voiping US
# 119                                      Moyyn
# 120  Eurecat - Centro Tecnológico de Catalunya
#
#                                   Location  \
# 0     Gerona, Cataluña, España (En remoto)
# 1    Barcelona, Cataluña, España (Híbrido)
# 2    Barcelona, Cataluña, España (Híbrido)
# 3     Badalona, Cataluña, España (Híbrido)
# 4              Barcelona, Cataluña, España
# ..                                     ...
# 116  Barcelona, Cataluña, España (Híbrido)
# 117            Barcelona, Cataluña, España
# 118                     España (En remoto)
# 119                     España (En remoto)
# 120    Manresa, Cataluña, España (Híbrido)
#
#                                            Description  \
# 0                  We are hiring freelance Spanish ...
# 1                  We are hiring freelance Spanish ...
# 2                  SummaryCarl Friedrik is a travel...
# 3                  Desde ISPROX estamos buscando in...
# 4                  About AgodaAgoda is an online tr...
# ..                                                 ...
# 116                Madbox is a mobile gaming compan...
# 117                         Este anuncio proviene d...
# 118                ¡En Voiping US seleccionamos Tal...
# 119                If you are a student, a recent g...
# 120                La UT Agua, Aire y Suelo (WAS) d...
#
#                                                  Terms     Regime
# 0                                                  GIT  En remoto
# 1                                                  GIT    Híbrido
# 2                   EXCEL, SQL, TABLEAU, RAG, BIGQUERY    Híbrido
# 3                     SQL, GIT, TABLEAU, MICROSTRATEGY    Híbrido
# 4    EXCEL, PYTHON, PANDAS, RAY, SQL, GIT, TABLEAU,...        NaN
# ..                                                 ...        ...
# 116                                           SQL, GIT    Híbrido
# 117                           SQL, QLIKSENSE, QLIKVIEW        NaN
# 118                                                     En remoto
# 119                                             PYTHON  En remoto
# 120                                         SCALA, SAS    Híbrido
#
# [121 rows x 6 columns]

# %%
df['Regime'].value_counts()
# Out:
# Híbrido       49
# En remoto     41
# Presencial    21
# Name: Regime, dtype: int64

# %%
N_offers = df['Title'].count()
N_hibrid = df[df['Regime']=='Híbrido']['Regime'].count()
N_remoto = df[df['Regime']=='En remoto']['Regime'].count()

print(round(N_hibrid*100/N_offers), " % híbrido")
print(round(N_remoto*100/N_offers), " % remoto")
# Out:
# 40  % híbrido
# 34  % remoto

# %% [markdown]
# ### Find years of experience required

# %%
import re
# Define a regular expression pattern for the desired text patterns
#pattern = r'(\d+)\s+(años de experiencia|years of experience)'
pattern = r'(\d+)\s*(-?\s*\d*)\s*(años de experiencia|years of experience)'
# Use re.findall to find matches directly
df['Experience'] = df['Description'].apply(lambda x: re.findall(pattern, x)[0] if re.findall(pattern, x) else None)

df_filtered = df.dropna(subset=['Experience'])
df_filtered
# Out:
#                                                  Title  \
# 3                         Data Engineer / Data Analyst
# 10                                  Data Analyst (AWS)
# 13                                        Data Analyst
# 18                                     BI Data Analyst
# 19                                     BI Data Analyst
# 34                                Digital Data Analyst
# 36                               Data Analyst Power BI
# 37                               Data Analyst Power BI
# 38                               Data Analyst Power BI
# 42                                        Data Analyst
# 43           Senior Game Data Analyst - Tarboosh Games
# 52                                        Data Analyst
# 54                  SENIOR DATA ANALYST - DIGITAL DATA
# 68   Global Commercial Data Analyst – Data Projects...
# 69   Business Intelligence Analyst Carreras Profesi...
# 70   Global Data Analyst - Partner Experience (They...
# 72                            DATA ANALYST - RETENTION
# 93                  Senior Data Analyst - (Growth, HQ)
# 97                    Business Intelligence Consultant
# 99                     Power BI Consultant (Barcelona)
# 100                    Power BI Consultant (Barcelona)
# 101                      Business Intelligence Analyst
# 105                              Data Analyst Power BI
# 106                              Data Analyst Power BI
# 107                              Data Analyst Power BI
# 108                               Senior BI Consultant
# 114                             Senior Biostatistician
# 117                    Consultor Business Intelligence
#
#                                   Company  \
# 3                                  ISPROX
# 10                           knowmad mood
# 13                        Garaje de ideas
# 18                         eDreams ODIGEO
# 19                         eDreams ODIGEO
# 34                        Garaje de ideas
# 36                  Capgemini Engineering
# 37                  Capgemini Engineering
# 38                  Capgemini Engineering
# 42                              DDB Spain
# 43                                 Voodoo
# 52                                 ALOHAS
# 54                              CaixaBank
# 68                                Viatris
# 69                               EsadeGov
# 70                                  Glovo
# 72   MCR International | Executive Search
# 93                                  Glovo
# 97                                Lognext
# 99                      HR NET CONSULTING
# 100                     HR NET CONSULTING
# 101                              EsadeGov
# 105                             Capgemini
# 106                             Capgemini
# 107                             Capgemini
# 108             Mason Frank International
# 114                     RTI International
# 117                             Consulsap
#
#                                      Location  \
# 3        Badalona, Cataluña, España (Híbrido)
# 10        Barcelona y alrededores (En remoto)
# 13          Barcelona y alrededores (Híbrido)
# 18      Barcelona, Cataluña, España (Híbrido)
# 19      Barcelona, Cataluña, España (Híbrido)
# 34                         España (En remoto)
# 36      Barcelona, Cataluña, España (Híbrido)
# 37      Barcelona, Cataluña, España (Híbrido)
# 38      Barcelona, Cataluña, España (Híbrido)
# 42      Barcelona, Cataluña, España (Híbrido)
# 43    Barcelona, Cataluña, España (En remoto)
# 52      Barcelona, Cataluña, España (Híbrido)
# 54   Barcelona, Cataluña, España (Presencial)
# 68                         España (En remoto)
# 69    Barcelona, Cataluña, España (En remoto)
# 70      Barcelona, Cataluña, España (Híbrido)
# 72   Barcelona, Cataluña, España (Presencial)
# 93      Barcelona, Cataluña, España (Híbrido)
# 97                         España (En remoto)
# 99   Barcelona, Cataluña, España (Presencial)
# 100  Barcelona, Cataluña, España (Presencial)
# 101     Barcelona, Cataluña, España (Híbrido)
# 105     Barcelona, Cataluña, España (Híbrido)
# 106     Barcelona, Cataluña, España (Híbrido)
# 107     Barcelona, Cataluña, España (Híbrido)
# 108  Barcelona, Cataluña, España (Presencial)
# 114     Barcelona, Cataluña, España (Híbrido)
# 117               Barcelona, Cataluña, España
#
#                                            Description  \
# 3                  Desde ISPROX estamos buscando in...
# 10                 ¡Somos knowmad mood, anteriormen...
# 13                 Lo que buscamos es…Un/a Data Ana...
# 18                 eDreams ODIGEO is one of the wor...
# 19                 eDreams ODIGEO is one of the wor...
# 34                 Lo que buscamos es…Un/a Digital ...
# 36                 ¡Hola! Somos CAPGEMINITenemos la...
# 37                 ¡Hola! Somos CAPGEMINITenemos la...
# 38                 ¡Hola! Somos CAPGEMINITenemos la...
# 42                 Para nuestra oficina de DDB Barc...
# 43                 Voodoo is a tech company that cr...
# 52                 ALOHAS is more than a fashion br...
# 54                 Descripció del lloc de treball:¿...
# 68                 7090 Mylan Healthcare Sp. z o.oA...
# 69                          Este anuncio proviene d...
# 70                 If you’re here, it’s because you...
# 72                 Descripción Del Trabajo / Job De...
# 93                 If you’re here, it’s because you...
# 97                 OGNEXT es una consultora IT con ...
# 99                 Buscamos Power BI Consultant par...
# 100                Buscamos Power BI Consultant par...
# 101                         Este anuncio proviene d...
# 105                ¡Hola! Somos CAPGEMINITenemos la...
# 106                ¡Hola! Somos CAPGEMINITenemos la...
# 107                ¡Hola! Somos CAPGEMINITenemos la...
# 108                Responsibilities Conduct Require...
# 114                OverviewRTI Health Solutions (RT...
# 117                         Este anuncio proviene d...
#
#                                                  Terms      Regime  \
# 3                     SQL, GIT, TABLEAU, MICROSTRATEGY     Híbrido
# 10      AWS, SNOWFLAKE, SQL, SNOWFLAKE, SAS, SNOWFLAKE   En remoto
# 13   DBT, GOOGLE CLOUD, SQL, GIT, TABLEAU, SAS, GOO...     Híbrido
# 18   EXCEL, PYTHON, GOOGLE CLOUD, SQL, GIT, RAG, MI...     Híbrido
# 19   EXCEL, PYTHON, GOOGLE CLOUD, SQL, GIT, RAG, MI...     Híbrido
# 34                     GIT, GOOGLE ANALYTICS, BIGQUERY   En remoto
# 36          EXCEL, PYTHON, POWER BI, DAX, VISUAL BASIC     Híbrido
# 37          EXCEL, PYTHON, POWER BI, DAX, VISUAL BASIC     Híbrido
# 38          EXCEL, PYTHON, POWER BI, DAX, VISUAL BASIC     Híbrido
# 42               EXCEL, GIT, POWER BI, ADOBE ANALYTICS     Híbrido
# 43                                    PYTHON, SQL, RAG   En remoto
# 52                                  EXCEL, PYTHON, SQL     Híbrido
# 54   EXCEL, RAY, SQL, GIT, ADOBE ANALYTICS, GOOGLE ...  Presencial
# 68                        EXCEL, PYTHON, AWS, SQL, RAG   En remoto
# 69               EXCEL, GIT, RAG, POWER BI, SALESFORCE   En remoto
# 70                                     EXCEL, SQL, RAG     Híbrido
# 72                                                      Presencial
# 93           EXCEL, PYTHON, SQL, RAG, GOOGLE ANALYTICS     Híbrido
# 97         EXCEL, SNOWFLAKE, SQL, SNOWFLAKE, SNOWFLAKE   En remoto
# 99                                EXCEL, POWER BI, DAX  Presencial
# 100                               EXCEL, POWER BI, DAX  Presencial
# 101              EXCEL, GIT, RAG, POWER BI, SALESFORCE     Híbrido
# 105         EXCEL, PYTHON, POWER BI, DAX, VISUAL BASIC     Híbrido
# 106         EXCEL, PYTHON, POWER BI, DAX, VISUAL BASIC     Híbrido
# 107         EXCEL, PYTHON, POWER BI, DAX, VISUAL BASIC     Híbrido
# 108                          EXCEL, SQL, POWER BI, DAX  Presencial
# 114                                                SAS     Híbrido
# 117                           SQL, QLIKSENSE, QLIKVIEW         NaN
#
#                         Experience
# 3       (4, , años de experiencia)
# 10      (3, , años de experiencia)
# 13      (5, , años de experiencia)
# 18      (3, , years of experience)
# 19      (3, , years of experience)
# 34      (5, , años de experiencia)
# 36      (3, , años de experiencia)
# 37      (3, , años de experiencia)
# 38      (3, , años de experiencia)
# 42    (2, -3, años de experiencia)
# 43      (2, , years of experience)
# 52      (2, , years of experience)
# 54      (5, , años de experiencia)
# 68   (5, - 7, years of experience)
# 69      (4, , years of experience)
# 70    (2, -3, years of experience)
# 72      (5, , years of experience)
# 93    (3, -5, years of experience)
# 97     (15, , años de experiencia)
# 99      (5, , años de experiencia)
# 100     (5, , años de experiencia)
# 101     (4, , years of experience)
# 105     (3, , años de experiencia)
# 106     (3, , años de experiencia)
# 107     (3, , años de experiencia)
# 108     (4, , years of experience)
# 114     (5, , years of experience)
# 117     (3, , años de experiencia)

# %%
df.iloc[52]['Description']
# Out:
# '              Desde el equipo de LIGHTHOUSE, nuestra área de Data & Analytics, ayudamos a nuestros clientes a encontrar la eficiencia y el alto rendimiento en todas sus funciones TIC, tanto internas como externas hacia sus unidades de negocio y proveedores: buscando la máxima eficiencia en la operación de sus servicios y ajustando sus costes; así como incrementando su trascendencia en la cuenta de resultados y facilitando la innovación.Actualmente, nos encontramos en proceso de crecimiento y estamos buscando un/a Manager Data Scientist para incorporarse al equipo.¿Qué podrás hacer?  Gestionar la preparación, entrega, informes, lanzamiento, monitorización y evaluación de proyectos y compromisos asignados, asumiendo la responsabilidad de los proyectos D&A y compromisos de mayor riesgo.  Supervisar el desarrollo de la Estrategia D&A: Definición de objetivos y áreas de valor, casos de uso, arquitecturas y tecnologías, mapas de información interna / externa y roadmapsde adopción de Big Data.  Asesorar sobre estrategias analíticas ayudando a los clientes en la construcción de una empresa “Data Driven”, mediante la transformación de la información disponible, para ofrecer valor a la organización, procesos y tecnología.  Desarrollar modelos y tecnologías advanced analytics que permiten seleccionar las soluciones adecuadas para procesar la información estructurada y no estructurada procedentes de dentro y fuera de la organización.  Proponer modelos, soluciones y arquitecturas analíticas que permiten complementar las capacidades de nuestros clientes.  Responsable del diseño la infraestructura y las soluciones de almacenamiento, procesamiento y visualización de la información.  Evalúa el desempeño del trabajo realizado por los miembros de los equipos de los proyectos que tiene asignados, siendo capaz de desarrollar, motivar y aconsejar, aportando claridad al trabajo del equipo en el proyecto, y recogiendo su esfuerzo y compromiso.  ¿Qué necesitas saber?  Tener entre 5-10 años de experiencia ejecutando poryetos de Data Analytics: Data Governance, BI, Advanced Analytics, Automatzación, Process Mining...  Experiencia en gestion de equipos Experiencia en el desarrollo de modelos y tecnologías advanced analytics Red de contactos de clientes'

# %% [markdown]
# ### Find salary

# %%
import re
# Define a regular expression pattern for the desired text patterns
pattern = r'(\d[\d,\.]*)\s*(EUR|€|eur|euros)' 

# Use re.findall to find matches directly
df['Salary'] = df['Description'].apply(lambda x: re.findall(pattern, x)[0] if re.findall(pattern, x) else None)

df_filtered = df.dropna(subset=['Salary'])
df_filtered
# Out:
#                                                  Title               Company  \
# 39                                       Data Engineer                Akuaro
# 101   Intern Support Project Management & Data Steward    Schneider Electric
# 133  Junior Big Data Engineer (Tech Support) - Goog...               Webhelp
# 166                                     Data Architect  Oxigent Technologies
#
#                                               Location  \
# 39               Barcelona, Cataluña, España (Híbrido)
# 101            Barcelona, Cataluña, España (En remoto)
# 133              Barcelona, Cataluña, España (Híbrido)
# 166  Cornellà de Llobregat, Cataluña, España (Híbrido)
#
#                                            Description  \
# 39                 Here we go!!Join a thriving and ...
# 101                ¿Quieres vivir la experiencia de...
# 133                WHAT WE LOOK FORAre you looking ...
# 166                ¿Te interesaría seguir desarroll...
#
#                                                  Terms     Regime Experience  \
# 39                      EXCEL, PYTHON, AWS, GCP, AZURE    Híbrido       None
# 101                                         EXCEL, GIT  En remoto       None
# 133  PYTHON, SPARK, GOOGLE CLOUD, AZURE, SQL, AIRFL...    Híbrido       None
# 166                                 PYTHON, SPARK, SQL    Híbrido       None
#
#             Salary
# 39     (45,000, €)
# 101       (900, €)
# 133    (30.040, €)
# 166  (45.000, eur)

# %% [markdown]
# ### Find other relevant terms and extract the phrase they appear in

# %%
# Define a regular expression pattern for the desired text patterns
pattern = r'(salario|salary|remuneración)' 

# Use re.findall to find matches directly
df['Salary2'] = df['Description'].apply(lambda x: re.findall(pattern, x)[0] if re.findall(pattern, x) else None)

df_filtered1 = df.dropna(subset=['Salary2'])
df_filtered1
# Out:
#                                                  Title  \
# 2                                         Data Analyst
# 3                         Data Engineer / Data Analyst
# 11                            Data Analyst - Thingworx
# 13                                        Data Analyst
# 23               Underwriter and Business Data Analyst
# 25                                  Data Analyst, EMEA
# 34                                Digital Data Analyst
# 41                                        Data Analyst
# 43           Senior Game Data Analyst - Tarboosh Games
# 46                                 Senior Data Analyst
# 57                                   Lead Data Analyst
# 61   Beca en Allianz Seguros - Analista de Datos (B...
# 64             Prácticas de Analista de datos (remoto)
# 69   Business Intelligence Analyst Carreras Profesi...
# 73                               Business Data Analyst
# 78             Analista de datos (prácticas en remoto)
# 83                           Data Analyst (SQL Wizard)
# 84                               Business Data Analyst
# 85     Data Analyst / Power BI Developer - 100% Remoto
# 86     Data Analyst / Power BI Developer - 100% Remoto
# 87     Data Analyst / Power BI Developer - 100% Remoto
# 89   Senior Data Analyst (Power BI) & AWS Services ...
# 90   Senior Data Analyst (Power BI) & AWS Services ...
# 91   Senior Data Analyst (Power BI) & AWS Services ...
# 101                      Business Intelligence Analyst
#
#                      Company                                  Location  \
# 2              Carl Friedrik     Barcelona, Cataluña, España (Híbrido)
# 3                     ISPROX      Badalona, Cataluña, España (Híbrido)
# 11        Between Technology  Barcelona, Cataluña, España (Presencial)
# 13           Garaje de ideas         Barcelona y alrededores (Híbrido)
# 23              AXA Partners     Barcelona, Cataluña, España (Híbrido)
# 25                    Criteo     Barcelona, Cataluña, España (Híbrido)
# 34           Garaje de ideas                        España (En remoto)
# 41                 Factorial  Barcelona, Cataluña, España (Presencial)
# 43                    Voodoo   Barcelona, Cataluña, España (En remoto)
# 46          Zurich Insurance     Barcelona, Cataluña, España (Híbrido)
# 57           Garaje de ideas                        España (En remoto)
# 61            Allianz España  Barcelona, Cataluña, España (Presencial)
# 64               HelloMrLead   Barcelona, Cataluña, España (En remoto)
# 69                  EsadeGov   Barcelona, Cataluña, España (En remoto)
# 73         GOOSE Recruitment     Barcelona, Cataluña, España (Híbrido)
# 78               HelloMrLead                        España (En remoto)
# 83           Diamond Foundry                 Unión Europea (En remoto)
# 84         GOOSE Recruitment     Barcelona, Cataluña, España (Híbrido)
# 85              Rhams Talent   Barcelona, Cataluña, España (En remoto)
# 86              Rhams Talent   Barcelona, Cataluña, España (En remoto)
# 87              Rhams Talent   Barcelona, Cataluña, España (En remoto)
# 89   Bluetab, an IBM Company                        España (En remoto)
# 90   Bluetab, an IBM Company                        España (En remoto)
# 91   Bluetab, an IBM Company                        España (En remoto)
# 101                 EsadeGov     Barcelona, Cataluña, España (Híbrido)
#
#                                            Description  \
# 2                  SummaryCarl Friedrik is a travel...
# 3                  Desde ISPROX estamos buscando in...
# 11                 ¿Te interesa trabajar en I+D den...
# 13                 Lo que buscamos es…Un/a Data Ana...
# 23                 In Axa Partners Spain we are loo...
# 25                 What You'll Do:At Criteo, we're ...
# 34                 Lo que buscamos es…Un/a Digital ...
# 41                 Hello! In Factorial we are looki...
# 43                 Voodoo is a tech company that cr...
# 46                 Our opportunity Are you passiona...
# 57                 Lo que buscamos es…Una persona c...
# 61                 Si estás finalizando tus estudio...
# 64                 Con esta oferta, de Prácticas de...
# 69                          Este anuncio proviene d...
# 73                 Are you an experienced Business ...
# 78                 Con esta oferta de prácticas de ...
# 83                 Diamond Foundry Inc. is solving ...
# 84                 Are you an experienced Business ...
# 85                 ⚠️ IMPORTANT: Only candidates ba...
# 86                 ⚠️ IMPORTANT: Only candidates ba...
# 87                 ⚠️ IMPORTANT: Only candidates ba...
# 89                 Bluetab, an IBM Company. certifi...
# 90                 Bluetab, an IBM Company. certifi...
# 91                 Bluetab, an IBM Company. certifi...
# 101                         Este anuncio proviene d...
#
#                                                  Terms      Regime  \
# 2                   EXCEL, SQL, TABLEAU, RAG, BIGQUERY     Híbrido
# 3                     SQL, GIT, TABLEAU, MICROSTRATEGY     Híbrido
# 11                               PYTHON, SQL, GIT, SAS  Presencial
# 13   DBT, GOOGLE CLOUD, SQL, GIT, TABLEAU, SAS, GOO...     Híbrido
# 23              EXCEL, PYTHON, SQL, POWER BI, DAX, SAS     Híbrido
# 25                      PYTHON, SQL, GIT, TABLEAU, RAG     Híbrido
# 34                     GIT, GOOGLE ANALYTICS, BIGQUERY   En remoto
# 41   PYTHON, AWS, SQL, GIT, POWER BI, MICROSTRATEGY...  Presencial
# 43                                    PYTHON, SQL, RAG   En remoto
# 46   PYTHON, SPARK, TABLEAU, RAG, POWER BI, DAX, QL...     Híbrido
# 57                                      GIT, AMPLITUDE   En remoto
# 61                           EXCEL, SQL, POWER BI, SAS  Presencial
# 64                                               EXCEL   En remoto
# 69               EXCEL, GIT, RAG, POWER BI, SALESFORCE   En remoto
# 73                      PYTHON, SQL, TABLEAU, POWER BI     Híbrido
# 78                                               EXCEL   En remoto
# 83   EXCEL, GOOGLE SHEETS, PYTHON, AWS, GCP, SQL, T...   En remoto
# 84                      PYTHON, SQL, TABLEAU, POWER BI     Híbrido
# 85                      EXCEL, SQL, RAG, POWER BI, SAS   En remoto
# 86                      EXCEL, SQL, RAG, POWER BI, SAS   En remoto
# 87                      EXCEL, SQL, RAG, POWER BI, SAS   En remoto
# 89    AWS, REDSHIFT, SQL, POWER BI, REDSHIFT, DAX, SAS   En remoto
# 90    AWS, REDSHIFT, SQL, POWER BI, REDSHIFT, DAX, SAS   En remoto
# 91    AWS, REDSHIFT, SQL, POWER BI, REDSHIFT, DAX, SAS   En remoto
# 101              EXCEL, GIT, RAG, POWER BI, SALESFORCE     Híbrido
#
#                      Experience       Salary2
# 2                          None        salary
# 3    (4, , años de experiencia)       salario
# 11                         None       salario
# 13   (5, , años de experiencia)       salario
# 23                         None  remuneración
# 25                         None        salary
# 34   (5, , años de experiencia)       salario
# 41                         None        salary
# 43   (2, , years of experience)        salary
# 46                         None        salary
# 57                         None       salario
# 61                         None  remuneración
# 64                         None  remuneración
# 69   (4, , years of experience)        salary
# 73                         None        salary
# 78                         None  remuneración
# 83                         None        salary
# 84                         None        salary
# 85                         None        salary
# 86                         None        salary
# 87                         None        salary
# 89                         None       salario
# 90                         None       salario
# 91                         None       salario
# 101  (4, , years of experience)        salary

# %%
df.iloc[4]['Description']
# Out:
# '              Si te consideras una persona analítica, autónoma y proactiva, con gran capacidad de comunicación y con un inglés fluido, tenemos una oportunidad para ti en nuestras oficinas de Barcelona.Como Data Scientist, contribuirás en la gestión de proyectos de Machine Learning en entorno Cloud, en contacto con stakeholders para desarrollar modelados estadísticos y predictivos.¿Qué te ofrecemos? 4-day work-week: trabajamos 34 horas dentro de una semana laboral de 4 días para potenciar la creatividad y la conciliación. Además, contamos con flexibilidad horaria de entrada y salida.Oficinas abiertas al mar: estamos en la Barceloneta frente al Mar Mediterráneo. Las vistas nos inspiran y el entorno nos permite disfrutar de una vida saludable: hacer deporte, llegar en bicicleta o caminando o comer al aire libre.Podrás flexibilizar tu salario destinándolo a servicios como seguro de salud, transporte, guardería y comida. Además podrás disfrutar de café, infusiones y fruta fresca cada día.Desigualiza tu armario: tendrás un 50% de descuento en nuestras colecciones. ¿Qué buscamos? Ingeniería Superior en Matemáticas, Estadística o informática.Experiencia de al menos 2 años como Data Scientist.Experiencia en el desarrollo de Modelos Predictivos y de Machine Learning.Experiencia en el uso de herramientas ML (Phyton, SQL, R,…)Nivel fluido de inglés.Habilidades de comunicación, trabajo en equipo, mente abierta.Capacidad de análisis.Capacidad de autonomía y proactividad.Además, se valorará positivamente:Experiencia con herramientas data discovery y data preparation.Experiencia en el deployment de proyectos de IA/ Machine Learning.Experiencia de forma activa en procesos de transformación de una compañía hacia una Data Driven Company. Tus funciones principales serán… Implementar productos Machine Learning en entorno Cloud (Snowflake, Azure, Amazon Sagemaker,..) sobre grandes volúmenes de datos y posterior seguimiento para garantizar la mejora continua de su rendimiento.Desarrollar y producir técnicas avanzadas de modelado estadístico y predictivo, trabajando en estrecha colaboración con los stakeholders.Tomar requerimientos con negocio, ejecutar e implantar proyectos analíticos.Dar seguimiento a todo el ciclo de vida de los proyectos: implicar y coordinar a los equipos internos y externos, estimar los recursos y tiempos para el desarrollo de las tareas, comunicar las soluciones analíticas a los stakeholders e implementar mejoras.Desarrollar nuevos e innovadores enfoques para resolver problemas analíticos.'

# %%
def find_sentence_around_word(description, target_word):
    pattern = re.compile(r'([^.]*\b' + re.escape(target_word) + r'\b[^.]*)', re.IGNORECASE)
    match = pattern.search(description)
    return match.group(1) if match else None

target_word = 'RAG'

# Create a new column 'Sentence_around_target'
df[f'Sentence_around_{target_word}'] = df['Description'].apply(lambda x: find_sentence_around_word(x, target_word))

df_filtered = df.dropna(subset=[f'Sentence_around_{target_word}'])
df_filtered
# Out:
# Empty DataFrame
# Columns: [Title, Company, Location, Description, Sentence_around_RAG]
# Index: []

# %%
df_filtered.iloc[2]['Sentence_around_chemistry']
# Out:
# ' Experience with search engines, classification algorithms, recommendation systems, and relevance evaluation methodologies Domain knowledge of research areas like chemistry, patent, life science is plus'

# %%
# Define a regular expression pattern for the desired text patterns
pattern = r'(Intern|Interino|Becario)' 

# Use re.findall to find matches directly
df['analyst'] = df['Title'].apply(lambda x: re.findall(pattern, x)[0] if re.findall(pattern, x) else None)

df_filtered1 = df.dropna(subset=['analyst'])
df_filtered1
# Out:
#                                            Title        Company  \
# 21                        Becario/a Data Analyst  Grupo Planeta
# 81  Operations Data Analyst Intern (They/She/He)          Glovo
#
#                                     Location  \
# 21  Barcelona, Cataluña, España (Presencial)
# 81     Barcelona, Cataluña, España (Híbrido)
#
#                                           Description  analyst  \
# 21                Estamos buscando un/a estudiante...  Becario
# 81                If you’re here, it’s because you...   Intern
#
#    Sentence_around_becario Sentence_around_interino  \
# 21                    None                     None
# 81                    None                     None
#
#                                Sentence_around_intern
# 21                                               None
# 81   We are looking for an Intern (Courier Growth)...

# %%
df.iloc[81]['Description']
# Out:
# "              If you’re here, it’s because you’re looking for an exciting ride.A ride that will fuel up your ambitions to take on a new challenge and stretch yourself beyond your comfort zone.We’ll deliver a non-vanilla culture built on talent, where we work to amplify the impact on millions of people, paving the way forward together.Not your usual app. We are the fastest-growing multi-category app connecting millions of users with businesses, and couriers, offering on-demand services from more than 170,000 local restaurants, grocers and supermarkets, and high street retail stores. We operate in more than 1500 cities across 25 countries. Every year, +200k merchants generate over 4B€ in sales through our platform and over 20M customers get their goods delivered in minutes.Together we revolutionize the way people connect with their everyday needs, from delivering essentials to connecting our ecosystem of users through innovative solutions powered by technology. For us, every day is filled with purpose.What makes our ride unique? 🤝 Our culture and strong values.  We have an ‘’office-first’’ culture and we place collaboration at the center of everything we do! We have a non-vanilla personality and feedback mindset. We don’t shy away from difficult conversations - we see them as a gift! We work with high intensity and have fun along the way. We also celebrate the wins (a lot!). We celebrate diversity in all its forms and foster an inclusive culture where everyone can bring their authentic selves to work.  💪Our career development philosophy.  We are building a talent house of high performing teams and leaders. We invest in people who raise the bar and help others reach their full potential. We take ownership of our career development. We don’t believe in linear and predictable career paths - we create the job of our dreams! We embrace opportunities to move the needle and make an impact beyond our scope.  🤝Our commitment to being a force for good.  Our platform is an important economic tool for millions of people (customers, partners, couriers) and we are taking action to amplify our positive impact. We invest in doing good by dedicating time and resources into social and environmental initiatives. We have the ambition of being DIB role models across the tech industry. We are creating environments, systems, and processes that provide equal opportunities, break biases, and empower our communities. We have a vision: To give everyone easy access to anything in their cities. And this is where your ride starts.YOUR MISSIONJoin us and become a key member of Glovo's Global operations team! We offer a challenging and dynamic environment with many opportunities for learning and development.The couriers are the key player in Glovo’s marketplace. We are looking for an Intern (Courier Growth) who will find the balance between creativity and data-driven objectivity in such a way that they carry out projects that seem impossible until they come true.You will be in charge of the lifecycle of the courier candidates, from the moment they register on the acquisition page until they start collaborating with us. You will ensure that we always have the highest conversion and quality in our courier onboarding process.THE JOURNEY Provide analytical support to the team of more than 20 countries, regional and local teams throughout deeper understanding of Glovo's operations model. Perform analysis to come up with insights to help improve KPIs in all the courier fleets around the world. Propose, track and consolidate new ideas to improve the courier funnel by being obsessed with Glovo's KPIs. Own the lifecycle of a courier candidate, from courier onboarding funnel optimisation to their first order. Innovate, build and maintain tools and processes related to the funnel backend. Own dashboards and build new tools to improve the visibility of metrics in the department. Understand and deep-dive into the data to understand the reasons and the levers we can act up ...
